# %%
import numpy as np 
import pandas as pd 
import seaborn as sb 

import statsmodels.api as sm 
from sklearn.linear_model import LinearRegression 

import nbformat 
from IPython import get_ipython

# %%
# %run "../Data_Preprocessing/data_preprocess.ipynb" 

with open("../Data_Preprocessing/data_preprocess.ipynb", "r", encoding="utf-8") as f:
    notebook1 = nbformat.read(f, as_version=4)

ipython = get_ipython() 

for cell in notebook1.cells:
    if cell.cell_type == "code":
        print(cell.source) 
        if ("movies_data_cleaned" in cell.source or "movie_colen_data" in cell.source):
            ipython.run_cell(cell.source, silent=True) 
            # ipython.run_cell_async(cell.source, silent=True) 

try:
    print("Movies Clean Data : ")
    print(movies_data_cleaned.head(), sep='\n')      # type: ignore 

except NameError as e:
    print(f"Variable not found: {e}")
# Out:
# import numpy as np
# import pandas as pd
# import seaborn as sb
# hp_d = pd.read_csv("../Datasets/House_Price.csv", header=0)
# hp_d
# shape_hp = hp_d.shape
# shape_hp
# hp_d.info()
# hp_d.describe()     # EDD process
# # hotel_rooms to price jointplot
#
# sb.jointplot(x = "n_hot_rooms", y = "price", data = hp_d)
# # rainfall to price
#
# sb.jointplot(x = "rainfall", y = "price", data=hp_d)
# # Airport availability in each city (classification - yes/no)
#
# sb.countplot(x="airport", data=hp_d)
# # Water body type count in each city (classification)
#
# sb.countplot(x="waterbody", data=hp_d)
# # bus terminal count
#
# sb.countplot(x="bus_ter", data=hp_d)
# np.percentile(hp_d.n_hot_rooms, [99])      # 99th percentile
# up_pctl = np.percentile(hp_d.n_hot_rooms, [99])[0]
# up_pctl
# hp_gt_pctl = hp_d[(hp_d.n_hot_rooms > up_pctl)]
# hp_gt_pctl
# # n_hot_rooms have upper percentile value 15.39, and the outlier values to be seen here are at index 2 and 423. So we handle it with (* 3x).
#
# # hp_d.n_hot_rooms[(hp_d.n_hot_rooms > (3 * up_pctl))] = 3 * up_pctl
#
# hp_d.loc[(hp_d.n_hot_rooms > (3 * up_pctl)), 'n_hot_rooms'] = 3 * up_pctl
# hp_gt_pctl = hp_d[(hp_d.n_hot_rooms > up_pctl)]
# hp_gt_pctl
# np.percentile(hp_d.rainfall, [1])       # 1st percentile of rainfall
# lw_pctl = np.percentile(hp_d.rainfall, [1])[0]
# lw_pctl
# hp_lw_pctl = hp_d[(hp_d.rainfall < lw_pctl)]
# hp_lw_pctl
# # rainfall have lower percentile value 20 , and the outlier values to be seen here is at index 213. So we handle it with (* 0.3x).
#
# hp_d.loc[(hp_d.rainfall < (0.3 * lw_pctl)), 'rainfall'] = 0.3 * lw_pctl
# hp_lw_pctl = hp_d[(hp_d.rainfall < lw_pctl)]
# hp_lw_pctl
# # sb.jointplot(x="resid_area", y="crime_rate", data=hp_d)
# sb.jointplot(y="price", x="crime_rate", data=hp_d)
# # Updated EDD, newer min for rainfall and max for hotel_room
#
# hp_d.describe()
# # Missing values handling
# # hp_d = hp_d.fillna(hp_d.mean())
#
# hp_d.n_hos_beds = hp_d.n_hos_beds.fillna(hp_d.n_hos_beds.mean())
# hp_d
#
# # hp_mean_hosbed = hp_d
# # hp_mean_hosbed
# hp_d.info()    # Updated table columns
# sb.jointplot(x="crime_rate", y="price", data=hp_d)
# # Since the crime rate is dense near the area of 0 to 1 for X-axis, wee have to add constant to the log function, for better view and calculation along with to get a linear relationship.
#
# # hp_d.crime_rate = np.log(1 + hp_d.crime_rate)
# hp_d.crime_rate = np.log(3 + hp_d.crime_rate)
# hp_d
# sb.jointplot(x="crime_rate", y="price", data=hp_d)     # Updated crime_rate to work with analysis
# # Avg_dist is avg. dist for all given dists..
#
# hp_d["Avg_dist"] = (hp_d.dist1 + hp_d.dist2 + hp_d.dist3 + hp_d.dist4) / 4
# hp_d
# print(hp_d.info())
# print(hp_d.describe())
# try:
#     del hp_d["dist1"]
#     print("Deleted dist1")
#     del hp_d["dist2"]
#     print("Deleted dist2")
#     del hp_d["dist3"]
#     print("Deleted dist3")
#     del hp_d["dist4"]
#     print("Deleted dist4")
# except Exception:
#     print("Error")
#
# print(hp_d.info())
# print(hp_d.describe())
# # Dummy variable/attribute creation for the attributes which hold categorical values and providing numerical attributes with 0 and 1.
# # Where 0 shows NIL for that categorical value and 1 holds true for it.
#
# hp_d = pd.get_dummies(hp_d)
# hp_d
#
# # hp_dms = pd.get_dummies(hp_d)
# # hp_dms
# hp_d[["airport_NO", "airport_YES", "waterbody_Lake", "waterbody_Lake and River", "waterbody_River"]] =  hp_d[["airport_NO", "airport_YES", "waterbody_Lake", "waterbody_Lake and River", "waterbody_River"]].astype(int)
# hp_d
#
# # Changing the type of dummy variables from bool to int type
# print(hp_d.info())
# print(hp_d.describe())
# del hp_d["airport_NO"]      # Removing extra quatifier whose meaning can be satisfies with the other airport_YES variable.
# print(hp_d.info())
# print(hp_d.describe())
# del hp_d["bus_ter_YES"]    # Since all the values hold true for the whole column
# hp_cleaned = hp_d
# # hp_cleaned
# hp_cleaned
# print(hp_cleaned.info())
# print(hp_cleaned.describe())
# # Correlation matrix , to find the attributes with correlation value 0.8 <= (attribute) <= 1.0 and remove other close to zero
# hp_cleaned.corr()
# movie_colen_data = pd.read_csv("../Datasets/Movie_collection_train.csv", header = 0)
# movie_colen_data
# movie_colen_data.shape
# movie_colen_data.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           506 non-null    int64
#  1   Marketin_expense     506 non-null    float64
#  2   Production_expense   506 non-null    float64
#  3   Multiplex_coverage   506 non-null    float64
#  4   Budget               506 non-null    float64
#  5   Movie_length         506 non-null    float64
#  6   Lead_ Actor_Rating   506 non-null    float64
#  7   Lead_Actress_rating  506 non-null    float64
#  8   Director_rating      506 non-null    float64
#  9   Producer_rating      506 non-null    float64
#  10  Critic_rating        506 non-null    float64
#  11  Trailer_views        506 non-null    int64
#  12  3D_available         506 non-null    object
#  13  Time_taken           494 non-null    float64
#  14  Twitter_hastags      506 non-null    float64
#  15  Genre                506 non-null    object
#  16  Avg_age_actors       506 non-null    int64
#  17  MPAA_film_rating     506 non-null    object
#  18  Num_multiplex        506 non-null    int64
#  19  Start_Tech_Oscar     506 non-null    int64
# dtypes: float64(12), int64(5), object(3)
# memory usage: 79.2+ KB
# movie_colen_data.describe()         # EDD process
# # Empty value handling with mean/median value filling
#
# # movie_colen_data.Time_taken = movie_colen_data.Time_taken.fillna(movie_colen_data.Time_taken.median())
# movie_colen_data.Time_taken = movie_colen_data.Time_taken.fillna(movie_colen_data.Time_taken.mean())
#
# movie_colen_data
# movie_colen_data.info()     # Handled and update tables with null values
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           506 non-null    int64
#  1   Marketin_expense     506 non-null    float64
#  2   Production_expense   506 non-null    float64
#  3   Multiplex_coverage   506 non-null    float64
#  4   Budget               506 non-null    float64
#  5   Movie_length         506 non-null    float64
#  6   Lead_ Actor_Rating   506 non-null    float64
#  7   Lead_Actress_rating  506 non-null    float64
#  8   Director_rating      506 non-null    float64
#  9   Producer_rating      506 non-null    float64
#  10  Critic_rating        506 non-null    float64
#  11  Trailer_views        506 non-null    int64
#  12  3D_available         506 non-null    object
#  13  Time_taken           506 non-null    float64
#  14  Twitter_hastags      506 non-null    float64
#  15  Genre                506 non-null    object
#  16  Avg_age_actors       506 non-null    int64
#  17  MPAA_film_rating     506 non-null    object
#  18  Num_multiplex        506 non-null    int64
#  19  Start_Tech_Oscar     506 non-null    int64
# dtypes: float64(12), int64(5), object(3)
# memory usage: 79.2+ KB
# sb.jointplot(x="Budget", y="Production_expense", data=movie_colen_data)
# sb.jointplot(data=movie_colen_data, x="Budget", y="Collection")
# sb.jointplot(data=movie_colen_data,x="Production_expense", y="Collection")
# sb.jointplot(data=movie_colen_data, x="Budget", y="Production_expense")
# # sb.relplot(data=movie_colen_data, y="Marketin_expense", x="Collection", hue="Movie_length", row="Budget", col="Movie_length")
#
# # sb.relplot(data=movie_colen_data, x="Marketin_expense", y="Collection")
# sb.jointplot(data=movie_colen_data, x="Marketin_expense", y="Collection")
# sb.jointplot(data=movie_colen_data, x="Budget", y="Marketin_expense")
# sb.jointplot(y="Marketin_expense", x="Production_expense", data=movie_colen_data)
# # movie_colen_data.Marketin_expense = np.log(2.5 + movie_colen_data.Marketin_expense)
# # movie_colen_data.Marketin_expense = np.log(3.0 + movie_colen_data.Marketin_expense)
# # movie_colen_data.Marketin_expense = np.log(1.5 + movie_colen_data.Marketin_expense)
# # movie_colen_data.Marketin_expense = np.log(2.0 + movie_colen_data.Marketin_expense)
#
# movie_colen_data.Marketin_expense = np.log(2.35 + movie_colen_data.Marketin_expense)
# movie_colen_data
# movie_colen_data.describe()     # Updated marketing expense attribute
# sb.jointplot(data=movie_colen_data, x="Marketin_expense", y="Collection")
# sb.jointplot(data=movie_colen_data, x="Budget", y="Marketin_expense")
# sb.jointplot(y="Marketin_expense", x="Production_expense", data=movie_colen_data)
# # Dummy variable creation for categorical values to be in numerical form
#
# movie_colen_data = pd.get_dummies(movie_colen_data)
# movie_colen_data
# movie_colen_data[["Genre_Action", "Genre_Comedy", "Genre_Drama", "Genre_Thriller", "3D_available_NO", "3D_available_YES"]] = movie_colen_data[["Genre_Action", "Genre_Comedy", "Genre_Drama", "Genre_Thriller", "3D_available_NO", "3D_available_YES"]].astype(int)
# movie_colen_data
# print(movie_colen_data.info())
# print(movie_colen_data.describe())
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           506 non-null    int64
#  1   Marketin_expense     506 non-null    float64
#  2   Production_expense   506 non-null    float64
#  3   Multiplex_coverage   506 non-null    float64
#  4   Budget               506 non-null    float64
#  5   Movie_length         506 non-null    float64
#  6   Lead_ Actor_Rating   506 non-null    float64
#  7   Lead_Actress_rating  506 non-null    float64
#  8   Director_rating      506 non-null    float64
#  9   Producer_rating      506 non-null    float64
#  10  Critic_rating        506 non-null    float64
#  11  Trailer_views        506 non-null    int64
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Avg_age_actors       506 non-null    int64
#  15  Num_multiplex        506 non-null    int64
#  16  Start_Tech_Oscar     506 non-null    int64
#  17  3D_available_NO      506 non-null    int64
#  18  3D_available_YES     506 non-null    int64
#  19  Genre_Action         506 non-null    int64
#  20  Genre_Comedy         506 non-null    int64
#  21  Genre_Drama          506 non-null    int64
#  22  Genre_Thriller       506 non-null    int64
#  23  MPAA_film_rating_PG  506 non-null    bool
# dtypes: bool(1), float64(12), int64(11)
# memory usage: 91.5 KB
# None
#           Collection  Marketin_expense  Production_expense  \
# count     506.000000        506.000000          506.000000
# mean    45057.707510          3.878959           77.273557
# std     18364.351764          0.986157           13.720706
# min     10000.000000          3.112466           55.920000
# 25%     34050.000000          3.177675           65.380000
# 50%     42400.000000          3.313464           74.380000
# 75%     50000.000000          4.563219           91.200000
# max    100000.000000          7.496583          110.480000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          506.000000    506.000000    506.000000          506.000000
# mean             0.445305  34911.144022    142.074901            8.014002
# std              0.115878   3903.038232     28.148861            1.054266
# min              0.129000  19781.355000     76.400000            3.840000
# 25%              0.376000  32693.952500    118.525000            7.316250
# 50%              0.462000  34488.217500    151.000000            8.307500
# 75%              0.551000  36793.542500    167.575000            8.865000
# max              0.615000  48772.900000    173.500000            9.435000
#
#        Lead_Actress_rating  Director_rating  Producer_rating  ...  \
# count           506.000000       506.000000       506.000000  ...
# mean              8.185613         8.019664         8.190514  ...
# std               1.054290         1.059899         1.049601  ...
# min               4.035000         3.840000         4.030000  ...
# 25%               7.503750         7.296250         7.507500  ...
# 50%               8.495000         8.312500         8.465000  ...
# 75%               9.030000         8.883750         9.030000  ...
# max               9.540000         9.425000         9.635000  ...
#
#        Twitter_hastags  Avg_age_actors  Num_multiplex  Start_Tech_Oscar  \
# count       506.000000      506.000000     506.000000        506.000000
# mean        260.832095       39.181818     545.043478          0.454545
# std         104.779133       12.513697     106.332889          0.498422
# min         201.152000        3.000000     333.000000          0.000000
# 25%         223.796000       28.000000     465.000000          0.000000
# 50%         254.400000       39.000000     535.500000          0.000000
# 75%         283.416000       50.000000     614.750000          1.000000
# max        2022.400000       60.000000     868.000000          1.000000
#
#        3D_available_NO  3D_available_YES  Genre_Action  Genre_Comedy  \
# count       506.000000        506.000000    506.000000    506.000000
# mean          0.448617          0.551383      0.140316      0.306324
# std           0.497845          0.497845      0.347659      0.461422
# min           0.000000          0.000000      0.000000      0.000000
# 25%           0.000000          0.000000      0.000000      0.000000
# 50%           0.000000          1.000000      0.000000      0.000000
# 75%           1.000000          1.000000      0.000000      1.000000
# max           1.000000          1.000000      1.000000      1.000000
#
#        Genre_Drama  Genre_Thriller
# count   506.000000      506.000000
# mean      0.191700        0.361660
# std       0.394028        0.480957
# min       0.000000        0.000000
# 25%       0.000000        0.000000
# 50%       0.000000        0.000000
# 75%       0.000000        1.000000
# max       1.000000        1.000000
#
# [8 rows x 23 columns]
# del movie_colen_data["3D_available_NO"]    # Extra attribute
# print(movie_colen_data.info())
# print(movie_colen_data.describe())
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           506 non-null    int64
#  1   Marketin_expense     506 non-null    float64
#  2   Production_expense   506 non-null    float64
#  3   Multiplex_coverage   506 non-null    float64
#  4   Budget               506 non-null    float64
#  5   Movie_length         506 non-null    float64
#  6   Lead_ Actor_Rating   506 non-null    float64
#  7   Lead_Actress_rating  506 non-null    float64
#  8   Director_rating      506 non-null    float64
#  9   Producer_rating      506 non-null    float64
#  10  Critic_rating        506 non-null    float64
#  11  Trailer_views        506 non-null    int64
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Avg_age_actors       506 non-null    int64
#  15  Num_multiplex        506 non-null    int64
#  16  Start_Tech_Oscar     506 non-null    int64
#  17  3D_available_YES     506 non-null    int64
#  18  Genre_Action         506 non-null    int64
#  19  Genre_Comedy         506 non-null    int64
#  20  Genre_Drama          506 non-null    int64
#  21  Genre_Thriller       506 non-null    int64
#  22  MPAA_film_rating_PG  506 non-null    bool
# dtypes: bool(1), float64(12), int64(10)
# memory usage: 87.6 KB
# None
#           Collection  Marketin_expense  Production_expense  \
# count     506.000000        506.000000          506.000000
# mean    45057.707510          3.878959           77.273557
# std     18364.351764          0.986157           13.720706
# min     10000.000000          3.112466           55.920000
# 25%     34050.000000          3.177675           65.380000
# 50%     42400.000000          3.313464           74.380000
# 75%     50000.000000          4.563219           91.200000
# max    100000.000000          7.496583          110.480000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          506.000000    506.000000    506.000000          506.000000
# mean             0.445305  34911.144022    142.074901            8.014002
# std              0.115878   3903.038232     28.148861            1.054266
# min              0.129000  19781.355000     76.400000            3.840000
# 25%              0.376000  32693.952500    118.525000            7.316250
# 50%              0.462000  34488.217500    151.000000            8.307500
# 75%              0.551000  36793.542500    167.575000            8.865000
# max              0.615000  48772.900000    173.500000            9.435000
#
#        Lead_Actress_rating  Director_rating  Producer_rating  ...  Time_taken  \
# count           506.000000       506.000000       506.000000  ...  506.000000
# mean              8.185613         8.019664         8.190514  ...  157.391498
# std               1.054290         1.059899         1.049601  ...   30.921101
# min               4.035000         3.840000         4.030000  ...    0.000000
# 25%               7.503750         7.296250         7.507500  ...  132.690000
# 50%               8.495000         8.312500         8.465000  ...  158.980000
# 75%               9.030000         8.883750         9.030000  ...  181.520000
# max               9.540000         9.425000         9.635000  ...  217.520000
#
#        Twitter_hastags  Avg_age_actors  Num_multiplex  Start_Tech_Oscar  \
# count       506.000000      506.000000     506.000000        506.000000
# mean        260.832095       39.181818     545.043478          0.454545
# std         104.779133       12.513697     106.332889          0.498422
# min         201.152000        3.000000     333.000000          0.000000
# 25%         223.796000       28.000000     465.000000          0.000000
# 50%         254.400000       39.000000     535.500000          0.000000
# 75%         283.416000       50.000000     614.750000          1.000000
# max        2022.400000       60.000000     868.000000          1.000000
#
#        3D_available_YES  Genre_Action  Genre_Comedy  Genre_Drama  \
# count        506.000000    506.000000    506.000000   506.000000
# mean           0.551383      0.140316      0.306324     0.191700
# std            0.497845      0.347659      0.461422     0.394028
# min            0.000000      0.000000      0.000000     0.000000
# 25%            0.000000      0.000000      0.000000     0.000000
# 50%            1.000000      0.000000      0.000000     0.000000
# 75%            1.000000      0.000000      1.000000     0.000000
# max            1.000000      1.000000      1.000000     1.000000
#
#        Genre_Thriller
# count      506.000000
# mean         0.361660
# std          0.480957
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
#
# [8 rows x 22 columns]
# del movie_colen_data["MPAA_film_rating_PG"]    # Since the whole colummn holds true
# movies_data_cleaned = movie_colen_data
# # movies_data_cleaned
# movies_data_cleaned
# print(movie_colen_data.info())
# print(movie_colen_data.describe())
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           506 non-null    int64
#  1   Marketin_expense     506 non-null    float64
#  2   Production_expense   506 non-null    float64
#  3   Multiplex_coverage   506 non-null    float64
#  4   Budget               506 non-null    float64
#  5   Movie_length         506 non-null    float64
#  6   Lead_ Actor_Rating   506 non-null    float64
#  7   Lead_Actress_rating  506 non-null    float64
#  8   Director_rating      506 non-null    float64
#  9   Producer_rating      506 non-null    float64
#  10  Critic_rating        506 non-null    float64
#  11  Trailer_views        506 non-null    int64
#  12  Time_taken           506 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Avg_age_actors       506 non-null    int64
#  15  Num_multiplex        506 non-null    int64
#  16  Start_Tech_Oscar     506 non-null    int64
#  17  3D_available_YES     506 non-null    int64
#  18  Genre_Action         506 non-null    int64
#  19  Genre_Comedy         506 non-null    int64
#  20  Genre_Drama          506 non-null    int64
#  21  Genre_Thriller       506 non-null    int64
# dtypes: float64(12), int64(10)
# memory usage: 87.1 KB
# None
#           Collection  Marketin_expense  Production_expense  \
# count     506.000000        506.000000          506.000000
# mean    45057.707510          3.878959           77.273557
# std     18364.351764          0.986157           13.720706
# min     10000.000000          3.112466           55.920000
# 25%     34050.000000          3.177675           65.380000
# 50%     42400.000000          3.313464           74.380000
# 75%     50000.000000          4.563219           91.200000
# max    100000.000000          7.496583          110.480000
#
#        Multiplex_coverage        Budget  Movie_length  Lead_ Actor_Rating  \
# count          506.000000    506.000000    506.000000          506.000000
# mean             0.445305  34911.144022    142.074901            8.014002
# std              0.115878   3903.038232     28.148861            1.054266
# min              0.129000  19781.355000     76.400000            3.840000
# 25%              0.376000  32693.952500    118.525000            7.316250
# 50%              0.462000  34488.217500    151.000000            8.307500
# 75%              0.551000  36793.542500    167.575000            8.865000
# max              0.615000  48772.900000    173.500000            9.435000
#
#        Lead_Actress_rating  Director_rating  Producer_rating  ...  Time_taken  \
# count           506.000000       506.000000       506.000000  ...  506.000000
# mean              8.185613         8.019664         8.190514  ...  157.391498
# std               1.054290         1.059899         1.049601  ...   30.921101
# min               4.035000         3.840000         4.030000  ...    0.000000
# 25%               7.503750         7.296250         7.507500  ...  132.690000
# 50%               8.495000         8.312500         8.465000  ...  158.980000
# 75%               9.030000         8.883750         9.030000  ...  181.520000
# max               9.540000         9.425000         9.635000  ...  217.520000
#
#        Twitter_hastags  Avg_age_actors  Num_multiplex  Start_Tech_Oscar  \
# count       506.000000      506.000000     506.000000        506.000000
# mean        260.832095       39.181818     545.043478          0.454545
# std         104.779133       12.513697     106.332889          0.498422
# min         201.152000        3.000000     333.000000          0.000000
# 25%         223.796000       28.000000     465.000000          0.000000
# 50%         254.400000       39.000000     535.500000          0.000000
# 75%         283.416000       50.000000     614.750000          1.000000
# max        2022.400000       60.000000     868.000000          1.000000
#
#        3D_available_YES  Genre_Action  Genre_Comedy  Genre_Drama  \
# count        506.000000    506.000000    506.000000   506.000000
# mean           0.551383      0.140316      0.306324     0.191700
# std            0.497845      0.347659      0.461422     0.394028
# min            0.000000      0.000000      0.000000     0.000000
# 25%            0.000000      0.000000      0.000000     0.000000
# 50%            1.000000      0.000000      0.000000     0.000000
# 75%            1.000000      0.000000      1.000000     0.000000
# max            1.000000      1.000000      1.000000     1.000000
#
#        Genre_Thriller
# count      506.000000
# mean         0.361660
# std          0.480957
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
#
# [8 rows x 22 columns]
# # movie_colen_data.corr()     # Correlatioin Matrix
# movies_data_cleaned.corr()     # Correlatioin Matrix
# Movies Clean Data :
#    Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0       48000          3.112466               59.62               0.462
# 1       43200          3.130971               69.14               0.531
# 2       69400          3.130953               69.14               0.531
# 3       66800          3.135381               59.36               0.542
# 4       72400          3.166782               59.36               0.542
#
#       Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0  36524.125         138.7               7.825                8.095
# 1  35668.655         152.4               7.505                7.650
# 2  39912.675         134.6               7.485                7.570
# 3  38873.890         119.3               6.895                7.035
# 4  39701.585         127.7               6.920                7.070
#
#    Director_rating  Producer_rating  ...  Time_taken  Twitter_hastags  \
# 0            7.910            7.995  ...      109.60          223.840
# 1            7.440            7.470  ...      146.64          243.456
# 2            7.495            7.515  ...      147.88         2022.400
# 3            6.920            7.020  ...      185.36          225.344
# 4            6.815            7.070  ...      176.48          225.792
#
#    Avg_age_actors  Num_multiplex  Start_Tech_Oscar  3D_available_YES  \
# 0              23            494                 0                 1
# 1              42            462                 1                 0
# 2              38            458                 0                 0
# 3              45            472                 0                 1
# 4              55            395                 0                 0
#
#    Genre_Action  Genre_Comedy  Genre_Drama  Genre_Thriller
# 0             0             0            0               1
# 1             0             0            1               0
# 2             0             1            0               0
# 3             0             0            1               0
# 4             0             0            1               0
#
# [5 rows x 22 columns]

# %%
movies_data_cleaned     # type: ignore
# Out:
#      Collection  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0         48000          3.112466               59.62               0.462
# 1         43200          3.130971               69.14               0.531
# 2         69400          3.130953               69.14               0.531
# 3         66800          3.135381               59.36               0.542
# 4         72400          3.166782               59.36               0.542
# ..          ...               ...                 ...                 ...
# 501       44800          3.161357               78.86               0.427
# 502       41200          3.146537               78.86               0.427
# 503       47800          3.159771               78.86               0.427
# 504       44000          3.200378               78.86               0.427
# 505       38000          3.148376               78.86               0.427
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0    36524.125         138.7               7.825                8.095
# 1    35668.655         152.4               7.505                7.650
# 2    39912.675         134.6               7.485                7.570
# 3    38873.890         119.3               6.895                7.035
# 4    39701.585         127.7               6.920                7.070
# ..         ...           ...                 ...                  ...
# 501  36624.115         142.6               8.680                8.775
# 502  33996.600         150.2               8.780                8.945
# 503  38751.680         164.5               8.830                8.970
# 504  37740.670         162.8               8.730                8.845
# 505  33496.650         154.3               8.640                8.880
#
#      Director_rating  Producer_rating  ...  Time_taken  Twitter_hastags  \
# 0              7.910            7.995  ...      109.60          223.840
# 1              7.440            7.470  ...      146.64          243.456
# 2              7.495            7.515  ...      147.88         2022.400
# 3              6.920            7.020  ...      185.36          225.344
# 4              6.815            7.070  ...      176.48          225.792
# ..               ...              ...  ...         ...              ...
# 501            8.620            8.970  ...      186.96          243.584
# 502            8.770            8.930  ...      132.24          263.296
# 503            8.855            9.010  ...      109.56          243.824
# 504            8.800            8.845  ...      158.80          303.520
# 505            8.680            8.790  ...      205.60          203.040
#
#      Avg_age_actors  Num_multiplex  Start_Tech_Oscar  3D_available_YES  \
# 0                23            494                 0                 1
# 1                42            462                 1                 0
# 2                38            458                 0                 0
# 3                45            472                 0                 1
# 4                55            395                 0                 0
# ..              ...            ...               ...               ...
# 501              27            561                 1                 0
# 502              20            600                 1                 1
# 503              31            576                 1                 0
# 504              47            607                 1                 1
# 505              45            604                 1                 1
#
#      Genre_Action  Genre_Comedy  Genre_Drama  Genre_Thriller
# 0               0             0            0               1
# 1               0             0            1               0
# 2               0             1            0               0
# 3               0             0            1               0
# 4               0             0            1               0
# ..            ...           ...          ...             ...
# 501             1             0            0               0
# 502             1             0            0               0
# 503             0             1            0               0
# 504             0             1            0               0
# 505             0             1            0               0
#
# [506 rows x 22 columns]

# %%
X_multi = movies_data_cleaned.drop('Collection', axis = 1)       # type: ignore 
X_multi
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0            3.112466               59.62               0.462  36524.125
# 1            3.130971               69.14               0.531  35668.655
# 2            3.130953               69.14               0.531  39912.675
# 3            3.135381               59.36               0.542  38873.890
# 4            3.166782               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 501          3.161357               78.86               0.427  36624.115
# 502          3.146537               78.86               0.427  33996.600
# 503          3.159771               78.86               0.427  38751.680
# 504          3.200378               78.86               0.427  37740.670
# 505          3.148376               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0           138.7               7.825                8.095            7.910
# 1           152.4               7.505                7.650            7.440
# 2           134.6               7.485                7.570            7.495
# 3           119.3               6.895                7.035            6.920
# 4           127.7               6.920                7.070            6.815
# ..            ...                 ...                  ...              ...
# 501         142.6               8.680                8.775            8.620
# 502         150.2               8.780                8.945            8.770
# 503         164.5               8.830                8.970            8.855
# 504         162.8               8.730                8.845            8.800
# 505         154.3               8.640                8.880            8.680
#
#      Producer_rating  Critic_rating  ...  Time_taken  Twitter_hastags  \
# 0              7.995           7.94  ...      109.60          223.840
# 1              7.470           7.44  ...      146.64          243.456
# 2              7.515           7.44  ...      147.88         2022.400
# 3              7.020           8.26  ...      185.36          225.344
# 4              7.070           8.26  ...      176.48          225.792
# ..               ...            ...  ...         ...              ...
# 501            8.970           6.80  ...      186.96          243.584
# 502            8.930           7.80  ...      132.24          263.296
# 503            9.010           7.80  ...      109.56          243.824
# 504            8.845           6.80  ...      158.80          303.520
# 505            8.790           6.80  ...      205.60          203.040
#
#      Avg_age_actors  Num_multiplex  Start_Tech_Oscar  3D_available_YES  \
# 0                23            494                 0                 1
# 1                42            462                 1                 0
# 2                38            458                 0                 0
# 3                45            472                 0                 1
# 4                55            395                 0                 0
# ..              ...            ...               ...               ...
# 501              27            561                 1                 0
# 502              20            600                 1                 1
# 503              31            576                 1                 0
# 504              47            607                 1                 1
# 505              45            604                 1                 1
#
#      Genre_Action  Genre_Comedy  Genre_Drama  Genre_Thriller
# 0               0             0            0               1
# 1               0             0            1               0
# 2               0             1            0               0
# 3               0             0            1               0
# 4               0             0            1               0
# ..            ...           ...          ...             ...
# 501             1             0            0               0
# 502             1             0            0               0
# 503             0             1            0               0
# 504             0             1            0               0
# 505             0             1            0               0
#
# [506 rows x 21 columns]

# %%
X_multi_cons = sm.add_constant(X_multi) 
X_multi_cons
# Out:
#      const  Marketin_expense  Production_expense  Multiplex_coverage  \
# 0      1.0          3.112466               59.62               0.462
# 1      1.0          3.130971               69.14               0.531
# 2      1.0          3.130953               69.14               0.531
# 3      1.0          3.135381               59.36               0.542
# 4      1.0          3.166782               59.36               0.542
# ..     ...               ...                 ...                 ...
# 501    1.0          3.161357               78.86               0.427
# 502    1.0          3.146537               78.86               0.427
# 503    1.0          3.159771               78.86               0.427
# 504    1.0          3.200378               78.86               0.427
# 505    1.0          3.148376               78.86               0.427
#
#         Budget  Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  \
# 0    36524.125         138.7               7.825                8.095
# 1    35668.655         152.4               7.505                7.650
# 2    39912.675         134.6               7.485                7.570
# 3    38873.890         119.3               6.895                7.035
# 4    39701.585         127.7               6.920                7.070
# ..         ...           ...                 ...                  ...
# 501  36624.115         142.6               8.680                8.775
# 502  33996.600         150.2               8.780                8.945
# 503  38751.680         164.5               8.830                8.970
# 504  37740.670         162.8               8.730                8.845
# 505  33496.650         154.3               8.640                8.880
#
#      Director_rating  Producer_rating  ...  Time_taken  Twitter_hastags  \
# 0              7.910            7.995  ...      109.60          223.840
# 1              7.440            7.470  ...      146.64          243.456
# 2              7.495            7.515  ...      147.88         2022.400
# 3              6.920            7.020  ...      185.36          225.344
# 4              6.815            7.070  ...      176.48          225.792
# ..               ...              ...  ...         ...              ...
# 501            8.620            8.970  ...      186.96          243.584
# 502            8.770            8.930  ...      132.24          263.296
# 503            8.855            9.010  ...      109.56          243.824
# 504            8.800            8.845  ...      158.80          303.520
# 505            8.680            8.790  ...      205.60          203.040
#
#      Avg_age_actors  Num_multiplex  Start_Tech_Oscar  3D_available_YES  \
# 0                23            494                 0                 1
# 1                42            462                 1                 0
# 2                38            458                 0                 0
# 3                45            472                 0                 1
# 4                55            395                 0                 0
# ..              ...            ...               ...               ...
# 501              27            561                 1                 0
# 502              20            600                 1                 1
# 503              31            576                 1                 0
# 504              47            607                 1                 1
# 505              45            604                 1                 1
#
#      Genre_Action  Genre_Comedy  Genre_Drama  Genre_Thriller
# 0               0             0            0               1
# 1               0             0            1               0
# 2               0             1            0               0
# 3               0             0            1               0
# 4               0             0            1               0
# ..            ...           ...          ...             ...
# 501             1             0            0               0
# 502             1             0            0               0
# 503             0             1            0               0
# 504             0             1            0               0
# 505             0             1            0               0
#
# [506 rows x 22 columns]

# %%
y_multi = movies_data_cleaned['Collection']       # type: ignore 
y_multi
# Out:
# 0      48000
# 1      43200
# 2      69400
# 3      66800
# 4      72400
#        ...
# 501    44800
# 502    41200
# 503    47800
# 504    44000
# 505    38000
# Name: Collection, Length: 506, dtype: int64

# %%
lm_multi = sm.OLS(y_multi, X_multi_cons).fit() 
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Collection   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     66.08
# Date:                Tue, 28 Oct 2025   Prob (F-statistic):          1.87e-124
# Time:                        19:38:08   Log-Likelihood:                -5352.8
# No. Observations:                 506   AIC:                         1.075e+04
# Df Residuals:                     485   BIC:                         1.084e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                -1.15e+05    1.3e+04     -8.874      0.000   -1.41e+05   -8.96e+04
# Marketin_expense    -1596.3152    683.914     -2.334      0.020   -2940.116    -252.515
# Production_expense    -95.7493     55.940     -1.712      0.088    -205.665      14.166
# Multiplex_coverage   2.827e+04   1.14e+04      2.482      0.013    5892.321    5.06e+04
# Budget                  1.7032      0.148     11.520      0.000       1.413       1.994
# Movie_length          -32.1016     26.729     -1.201      0.230     -84.620      20.416
# Lead_ Actor_Rating    731.3563   7335.114      0.100      0.921   -1.37e+04    1.51e+04
# Lead_Actress_rating -3653.8760   7845.733     -0.466      0.642   -1.91e+04    1.18e+04
# Director_rating      3294.3900   7618.461      0.432      0.666   -1.17e+04    1.83e+04
# Producer_rating      4810.3925   4102.576      1.173      0.242   -3250.625    1.29e+04
# Critic_rating        3978.3659    704.368      5.648      0.000    2594.377    5362.355
# Trailer_views           0.1137      0.010     10.876      0.000       0.093       0.134
# Time_taken             43.2478     14.402      3.003      0.003      14.951      71.545
# Twitter_hastags         0.9258      4.185      0.221      0.825      -7.297       9.148
# Avg_age_actors         16.5839     35.352      0.469      0.639     -52.878      86.046
# Num_multiplex          10.6101     10.214      1.039      0.299      -9.459      30.679
# Start_Tech_Oscar    -7854.5813    890.081     -8.825      0.000   -9603.472   -6105.691
# 3D_available_YES     1486.2579    902.761      1.646      0.100    -287.548    3260.063
# Genre_Action        -3.033e+04   3416.089     -8.879      0.000    -3.7e+04   -2.36e+04
# Genre_Comedy        -2.868e+04   3319.631     -8.640      0.000   -3.52e+04   -2.22e+04
# Genre_Drama         -2.815e+04   3379.244     -8.329      0.000   -3.48e+04   -2.15e+04
# Genre_Thriller      -2.788e+04   3250.235     -8.577      0.000   -3.43e+04   -2.15e+04
# ==============================================================================
# Omnibus:                      151.554   Durbin-Watson:                   1.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              590.843
# Skew:                           1.314   Prob(JB):                    5.01e-129
# Kurtosis:                       7.595   Cond. No.                     2.00e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.63e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
linr_reg = LinearRegression() 
linr_reg.fit(X_multi, y_multi) 

intercept, coef = linr_reg.intercept_ , linr_reg.coef_  
print(f"Multiple Linear Regression Model Intercept = {intercept}\nMultiple Linear Regression Model Coefficient = {coef}") 

# print(f"Multiple Linear Regression model Intercept = {intercept}\nMultiple Linear Regression Model Coefficient = {coef[0]}")
# Out:
# Multiple Linear Regression Model Intercept = -143793.01857012598
# Multiple Linear Regression Model Coefficient = [-1.59631521e+03 -9.57492876e+01  2.82673262e+04  1.70317944e+00
#  -3.21016113e+01  7.31356347e+02 -3.65387596e+03  3.29438995e+03
#   4.81039254e+03  3.97836588e+03  1.13678161e-01  4.32477876e+01
#   9.25779288e-01  1.65839453e+01  1.06100749e+01 -7.85458135e+03
#   1.48625786e+03 -1.57158082e+03  7.56291726e+01  6.13039196e+02
#   8.82912456e+02]
